# %%
# Basic Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
data = pd.read_csv('breeds.csv')

# %%
# Clean data

# Drop columns
columns_to_drop = ['a_adaptability', 'b_all_around_friendliness', 'c_health_grooming', 'd_trainability', 'e_exercise_needs']
cleanbreeds = data.drop(columns=columns_to_drop)

# Rename columns
new_column_names = {'a2_good_for_novice_owners': 'good for novice owners'}
cleanbreeds.rename(columns=new_column_names, inplace=True)

# %% [markdown]
# ## Finding the correlation between A2 and the other variables

# %% [markdown]
# A1

# %%
novice = pd.DataFrame(data['a2_good_for_novice_owners'])        # Response
a1 = pd.DataFrame(data['a1_adapts_well_to_apartment_living'])

# %%
# Create a joint dataframe by concatenating the two variables
jointDF = pd.concat([novice, a1], axis = 1).reindex(data.index)

jointDF.corr()
# Out:
#                                     a2_good_for_novice_owners  \
# a2_good_for_novice_owners                            1.000000
# a1_adapts_well_to_apartment_living                   0.560221
#
#                                     a1_adapts_well_to_apartment_living
# a2_good_for_novice_owners                                     0.560221
# a1_adapts_well_to_apartment_living                            1.000000

# %%
# Calculate the correlation between the two columns/variables
sb.heatmap(jointDF.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# A3

# %%
novice = pd.DataFrame(data['a2_good_for_novice_owners'])   # Response
a3 = pd.DataFrame(data['a3_sensitivity_level'])            # Predictor

# %%
# Create a joint dataframe by concatenating the two variables
jointDF = pd.concat([novice, a3], axis = 1).reindex(data.index)

jointDF.corr()
# Out:
#                            a2_good_for_novice_owners  a3_sensitivity_level
# a2_good_for_novice_owners                   1.000000              0.099593
# a3_sensitivity_level                        0.099593              1.000000

# %%
# Calculate the correlation between the two columns/variables
sb.heatmap(jointDF.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# A4

# %%
novice = pd.DataFrame(data['a2_good_for_novice_owners'])   # Response
a4 = pd.DataFrame(data['a4_tolerates_being_alone'])        # Predictor

# %%
# Create a joint dataframe by concatenating the two variables
jointDF = pd.concat([novice, a4], axis = 1).reindex(data.index)

jointDF.corr()
# Out:
#                            a2_good_for_novice_owners  a4_tolerates_being_alone
# a2_good_for_novice_owners                   1.000000                 -0.013542
# a4_tolerates_being_alone                   -0.013542                  1.000000

# %%
# Calculate the correlation between the two columns/variables
sb.heatmap(jointDF.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# A5

# %%
novice = pd.DataFrame(data['a2_good_for_novice_owners'])   # Response
a5 = pd.DataFrame(data['a5_tolerates_cold_weather'])       # Predictor

# %%
# Create a joint dataframe by concatenating the two variables
jointDF = pd.concat([novice, a5], axis = 1).reindex(data.index)

jointDF.corr()
# Out:
#                            a2_good_for_novice_owners  \
# a2_good_for_novice_owners                   1.000000
# a5_tolerates_cold_weather                  -0.207335
#
#                            a5_tolerates_cold_weather
# a2_good_for_novice_owners                  -0.207335
# a5_tolerates_cold_weather                   1.000000

# %%
# Calculate the correlation between the two columns/variables
sb.heatmap(jointDF.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# A6

# %%
novice = pd.DataFrame(data['a2_good_for_novice_owners'])   # Response
a6 = pd.DataFrame(data['a6_tolerates_hot_weather'])        # Predictor

# %%
# Calculate the correlation between the two columns/variables
sb.heatmap(jointDF.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# B1

# %%
novice = pd.DataFrame(data['a2_good_for_novice_owners'])   # Response
b1 = pd.DataFrame(data['b1_affectionate_with_family'])     # Predictor

# %%
# Create a joint dataframe by concatenating the two variables
jointDF = pd.concat([novice, b1], axis = 1).reindex(data.index)

jointDF.corr()
# Out:
#                              a2_good_for_novice_owners  \
# a2_good_for_novice_owners                     1.000000
# b1_affectionate_with_family                   0.110929
#
#                              b1_affectionate_with_family
# a2_good_for_novice_owners                       0.110929
# b1_affectionate_with_family                     1.000000

# %%
# Calculate the correlation between the two columns/variables
sb.heatmap(jointDF.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# B2

# %%
novice = pd.DataFrame(data['a2_good_for_novice_owners'])    # Response
b2 = pd.DataFrame(data['b2_incredibly_kid_friendly_dogs'])  # Predictor

# %%
# Create a joint dataframe by concatenating the two variables
jointDF = pd.concat([novice, b2], axis = 1).reindex(data.index)

jointDF.corr()
# Out:
#                                  a2_good_for_novice_owners  \
# a2_good_for_novice_owners                         1.000000
# b2_incredibly_kid_friendly_dogs                   0.106477
#
#                                  b2_incredibly_kid_friendly_dogs
# a2_good_for_novice_owners                               0.106477
# b2_incredibly_kid_friendly_dogs                         1.000000

# %%
# Calculate the correlation between the two columns/variables
sb.heatmap(jointDF.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# B3

# %%
novice = pd.DataFrame(data['a2_good_for_novice_owners'])  # Response
b3 = pd.DataFrame(data['b3_dog_friendly'])                # Predictor

# %%
# Create a joint dataframe by concatenating the two variables
jointDF = pd.concat([novice, b3], axis = 1).reindex(data.index)

jointDF.corr()
# Out:
#                            a2_good_for_novice_owners  b3_dog_friendly
# a2_good_for_novice_owners                   1.000000         0.292999
# b3_dog_friendly                             0.292999         1.000000

# %%
# Calculate the correlation between the two columns/variables
sb.heatmap(jointDF.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# B4

# %%
novice = pd.DataFrame(data['a2_good_for_novice_owners'])  # Response
b4 = pd.DataFrame(data['b4_friendly_toward_strangers'])   # Predictor

# %%
# Create a joint dataframe by concatenating the two variables
jointDF = pd.concat([novice, b4], axis = 1).reindex(data.index)

jointDF.corr()
# Out:
#                               a2_good_for_novice_owners  \
# a2_good_for_novice_owners                      1.000000
# b4_friendly_toward_strangers                   0.246014
#
#                               b4_friendly_toward_strangers
# a2_good_for_novice_owners                         0.246014
# b4_friendly_toward_strangers                      1.000000

# %%
# Calculate the correlation between the two columns/variables
sb.heatmap(jointDF.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >

# %%
goodForNovice = pd.DataFrame(data['a2_good_for_novice_owners'])
amtOfShedding = pd.DataFrame(data['c1_amount_of_shedding'])
drooling = pd.DataFrame(data['c2_drooling_potential'])
groom = pd.DataFrame(data['c3_easy_to_groom'])
health = pd.DataFrame(data['c4_general_health'])
weightGainPotential = pd.DataFrame(data['c5_potential_for_weight_gain'])
size = pd.DataFrame(data['c6_size'])

train = pd.DataFrame(data['d1_easy_to_train'])
intelligence = pd.DataFrame(data['d2_intelligence'])
mouthiness = pd.DataFrame(data['d3_potential_for_mouthiness'])
preyDrive = pd.DataFrame(data['d4_prey_drive'])
barkorHowl = pd.DataFrame(data['d5_tendency_to_bark_or_howl'])
wanderlust = pd.DataFrame(data['d6_wanderlust_potential'])

# %% [markdown]
# C1

# %%
DFc1 = pd.concat([goodForNovice, amtOfShedding], axis = 1).reindex(goodForNovice.index)
DFc1.corr()
# Out:
#                            a2_good_for_novice_owners  c1_amount_of_shedding
# a2_good_for_novice_owners                   1.000000              -0.208458
# c1_amount_of_shedding                      -0.208458               1.000000

# %%
sb.heatmap(DFc1.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# C2

# %%
DFc2 = pd.concat([goodForNovice, drooling], axis = 1).reindex(goodForNovice.index)
DFc2.corr()
# Out:
#                            a2_good_for_novice_owners  c2_drooling_potential
# a2_good_for_novice_owners                   1.000000              -0.301109
# c2_drooling_potential                      -0.301109               1.000000

# %%
sb.heatmap(DFc2.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# C3

# %%
DFc3 = pd.concat([goodForNovice, groom], axis = 1).reindex(goodForNovice.index)
DFc3.corr()
# Out:
#                            a2_good_for_novice_owners  c3_easy_to_groom
# a2_good_for_novice_owners                   1.000000         -0.087175
# c3_easy_to_groom                           -0.087175          1.000000

# %%
sb.heatmap(DFc3.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# C4

# %%
DFc4 = pd.concat([goodForNovice, health], axis = 1).reindex(goodForNovice.index)
DFc4.corr()
# Out:
#                            a2_good_for_novice_owners  c4_general_health
# a2_good_for_novice_owners                   1.000000          -0.032535
# c4_general_health                          -0.032535           1.000000

# %%
sb.heatmap(DFc4.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# C5

# %%
DFc5 = pd.concat([goodForNovice, weightGainPotential], axis = 1).reindex(goodForNovice.index)
DFc5.corr()
# Out:
#                               a2_good_for_novice_owners  \
# a2_good_for_novice_owners                       1.00000
# c5_potential_for_weight_gain                    0.06987
#
#                               c5_potential_for_weight_gain
# a2_good_for_novice_owners                          0.06987
# c5_potential_for_weight_gain                       1.00000

# %%
sb.heatmap(DFc5.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# C6

# %%
DFc6 = pd.concat([goodForNovice, size], axis = 1).reindex(goodForNovice.index)
DFc6.corr()
# Out:
#                            a2_good_for_novice_owners   c6_size
# a2_good_for_novice_owners                   1.000000 -0.508582
# c6_size                                    -0.508582  1.000000

# %%
sb.heatmap(DFc6.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# D1

# %%
DFd1 = pd.concat([goodForNovice, train], axis = 1).reindex(goodForNovice.index)
DFd1.corr()
# Out:
#                            a2_good_for_novice_owners  d1_easy_to_train
# a2_good_for_novice_owners                   1.000000          0.211637
# d1_easy_to_train                            0.211637          1.000000

# %%
sb.heatmap(DFd1.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# D2

# %%
DFd2 = pd.concat([goodForNovice, intelligence], axis = 1).reindex(goodForNovice.index)
DFd2.corr()
# Out:
#                            a2_good_for_novice_owners  d2_intelligence
# a2_good_for_novice_owners                   1.000000        -0.039965
# d2_intelligence                            -0.039965         1.000000

# %%
sb.heatmap(DFd2.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# D3

# %%
DFd3 = pd.concat([goodForNovice, mouthiness], axis = 1).reindex(goodForNovice.index)
DFd3.corr()
# Out:
#                              a2_good_for_novice_owners  \
# a2_good_for_novice_owners                     1.000000
# d3_potential_for_mouthiness                  -0.161983
#
#                              d3_potential_for_mouthiness
# a2_good_for_novice_owners                      -0.161983
# d3_potential_for_mouthiness                     1.000000

# %%
sb.heatmap(DFd3.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# D4

# %%
DFd4 = pd.concat([goodForNovice, preyDrive], axis = 1).reindex(goodForNovice.index)
DFd4.corr()
# Out:
#                            a2_good_for_novice_owners  d4_prey_drive
# a2_good_for_novice_owners                   1.000000      -0.143348
# d4_prey_drive                              -0.143348       1.000000

# %%
sb.heatmap(DFd4.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# D5

# %%
DFd5 = pd.concat([goodForNovice, barkorHowl], axis = 1).reindex(goodForNovice.index)
DFd5.corr()
# Out:
#                              a2_good_for_novice_owners  \
# a2_good_for_novice_owners                     1.000000
# d5_tendency_to_bark_or_howl                  -0.038071
#
#                              d5_tendency_to_bark_or_howl
# a2_good_for_novice_owners                      -0.038071
# d5_tendency_to_bark_or_howl                     1.000000

# %%
sb.heatmap(DFd5.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# D6

# %%
DFd6 = pd.concat([goodForNovice, wanderlust], axis = 1).reindex(goodForNovice.index)
DFd6.corr()
# Out:
#                            a2_good_for_novice_owners  d6_wanderlust_potential
# a2_good_for_novice_owners                   1.000000                -0.188797
# d6_wanderlust_potential                    -0.188797                 1.000000

# %%
sb.heatmap(DFd6.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >

# %%
new_df1 = data[['a2_good_for_novice_owners', 'e1_energy_level', 'e2_intensity', 'e3_exercise_needs', 'e4_potential_for_playfulness']].copy()
new_df1.head()
# Out:
#    a2_good_for_novice_owners  e1_energy_level  e2_intensity  \
# 0                          1                4             4
# 1                          4                4             3
# 2                          4                4             3
# 3                          3                5             2
# 4                          2                5             3
#
#    e3_exercise_needs  e4_potential_for_playfulness
# 0                  4                             3
# 1                  3                             3
# 2                  3                             4
# 3                  4                             4
# 4                  5                             5

# %% [markdown]
# e1

# %%
novice = pd.DataFrame(data['a2_good_for_novice_owners'])        # Response
e1 = pd.DataFrame(data['e1_energy_level'])

# %%
jointDFe1 = pd.concat([novice, e1], axis = 1).reindex(data.index)

jointDFe1.corr()
# Out:
#                            a2_good_for_novice_owners  e1_energy_level
# a2_good_for_novice_owners                   1.000000        -0.196646
# e1_energy_level                            -0.196646         1.000000

# %%
# Calculate the correlation between the two columns/variables
sb.heatmap(jointDFe1.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# e2

# %%
novice = pd.DataFrame(data['a2_good_for_novice_owners'])        # Response
e2 = pd.DataFrame(data['e2_intensity'])

# %%
jointDFe2 = pd.concat([novice, e2], axis = 1).reindex(data.index)

jointDFe2.corr()
# Out:
#                            a2_good_for_novice_owners  e2_intensity
# a2_good_for_novice_owners                   1.000000     -0.315446
# e2_intensity                               -0.315446      1.000000

# %%
# Calculate the correlation between the two columns/variables
sb.heatmap(jointDFe2.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# e3

# %%
novice = pd.DataFrame(data['a2_good_for_novice_owners'])        # Response
e3 = pd.DataFrame(data['e3_exercise_needs'])

# %%
jointDFe3 = pd.concat([novice, e3], axis = 1).reindex(data.index)

jointDFe3.corr()
# Out:
#                            a2_good_for_novice_owners  e3_exercise_needs
# a2_good_for_novice_owners                   1.000000          -0.351809
# e3_exercise_needs                          -0.351809           1.000000

# %%
# Calculate the correlation between the two columns/variables
sb.heatmap(jointDFe3.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# e4

# %%
novice = pd.DataFrame(data['a2_good_for_novice_owners'])        # Response
e4 = pd.DataFrame(data['e4_potential_for_playfulness'])

# %%
jointDFe4 = pd.concat([novice, e4], axis = 1).reindex(data.index)

jointDFe4.corr()
# Out:
#                               a2_good_for_novice_owners  \
# a2_good_for_novice_owners                       1.00000
# e4_potential_for_playfulness                    0.10377
#
#                               e4_potential_for_playfulness
# a2_good_for_novice_owners                          0.10377
# e4_potential_for_playfulness                       1.00000

# %%
# Calculate the correlation between the two columns/variables
sb.heatmap(jointDFe4.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# ## Cleaning the data

# %%
new_df2 = data[['a2_good_for_novice_owners', 'breed_group', 'height', 'weight', 'life_span']].copy()

pd.set_option('display.max_rows', None)  # This will allow all rows to be displayed.
pd.set_option('display.max_columns', None)  # This will allow all columns to be displayed.
pd.set_option('display.width', None)  # This aims to ensure that the display is not truncated horizontally.
pd.set_option('display.max_colwidth', None)  # This will allow the full width of column data to be displayed.

new_df2
# Out:
#      a2_good_for_novice_owners       breed_group  \
# 0                            1  Mixed Breed Dogs
# 1                            4  Mixed Breed Dogs
# 2                            4    Companion Dogs
# 3                            3        Hound Dogs
# 4                            2      Terrier Dogs
# 5                            2      Working Dogs
# 6                            2      Working Dogs
# 7                            2    Companion Dogs
# 8                            1      Working Dogs
# 9                            1      Working Dogs
# 10                           2        Hound Dogs
# 11                           4    Companion Dogs
# 12                           2        Hound Dogs
# 13                           4        Hound Dogs
# 14                           2      Terrier Dogs
# 15                           3  Mixed Breed Dogs
# 16                           2      Terrier Dogs
# 17                           2     Sporting Dogs
# ...

# %%
def process_weight_column(df, column_name):
    # Split the weight column into min_weight and max_weight
    weight_split = df[column_name].str.extract(r'(\d+)\s+to\s+(\d+)')
    df['min_weight'] = pd.to_numeric(weight_split[0], errors='coerce')
    df['max_weight'] = pd.to_numeric(weight_split[1], errors='coerce')

    # Handle special cases like 'Up to X pounds' and 'Starts at X pounds'
    up_to = df[column_name].str.extract(r'Up to (\d+)')
    starts_at = df[column_name].str.extract(r'Starts at (\d+)')
    
    # Apply the extracted values appropriately
    df.loc[up_to[0].notnull(), 'min_weight'] = 1  # Assuming 1 pound as a realistic minimum
    df.loc[up_to[0].notnull(), 'max_weight'] = pd.to_numeric(up_to[0], errors='coerce')
    
    df.loc[starts_at[0].notnull(), 'min_weight'] = pd.to_numeric(starts_at[0], errors='coerce')
    df.loc[starts_at[0].notnull(), 'max_weight'] = pd.NA

    # Replace NaN values with the column's average
    min_weight_avg = df['min_weight'].mean()
    max_weight_avg = df['max_weight'].mean()
    df['min_weight'] = df['min_weight'].fillna(min_weight_avg)
    df['max_weight'] = df['max_weight'].fillna(max_weight_avg)

    return df

process_weight_column(new_df2, 'weight')

new_df2[['weight', 'min_weight', 'max_weight']]
# Out:
#                    weight  min_weight  max_weight
# 0         50 to 75 pounds   50.000000   75.000000
# 1          4 to 12 pounds    4.000000   12.000000
# 2           7 to 9 pounds    7.000000    9.000000
# 3         50 to 60 pounds   50.000000   60.000000
# 4         40 to 65 pounds   40.000000   65.000000
# 5        75 to 140 pounds   75.000000  140.000000
# 6        70 to 130 pounds   70.000000  130.000000
# 7         10 to 15 pounds   10.000000   15.000000
# 8        75 to 100 pounds   75.000000  100.000000
# 9        60 to 120 pounds   60.000000  120.000000
# 10                    NaN   35.701754   59.384615
# 11    Starts at 30 pounds   30.000000   59.384615
# 12        40 to 60 pounds   40.000000   60.000000
# 13      35 to 75 pounds.    35.000000   75.000000
# 14        30 to 85 pounds   30.000000   85.000000
# 15       25 to 70 pounds    25.000000   70.000000
# 16        40 to 60 pounds   40.000000   60.000000
# 17        25 to 45 pounds   25.000000   45.000000
# ...

# %%
import pandas as pd
import re

def process_height_column(df, column_name):
    def parse_height_to_inches(height_str):
        """
        Converts a height string into inches.
        Handles single values, ranges, and phrases with 'Up to' or 'From'.
        Sets min_height to 1 if 'Up to' is found, uses the actual value for 'From',
        and calculates range if 'to' is present.
        """
        if pd.isna(height_str):
            return None, None

        # Identify if the string contains 'Up to', 'From', or a range indicated by 'to'
        up_to_match = re.search(r'up to', height_str, re.IGNORECASE)
        from_match = re.search(r'from', height_str, re.IGNORECASE)
        to_match = re.search(r'to', height_str, re.IGNORECASE)

        # Initialize min_height and max_height
        min_height, max_height = None, None

        # Function to parse height in inches from a given string part
        def get_inches(part):
            inches_total = 0
            for num in re.finditer(r'(\d+)\s*(foot|feet|inch|inches)?', part, re.IGNORECASE):
                value, unit = int(num.group(1)), num.group(2)
                if unit and ('foot' in unit or 'feet' in unit):
                    inches_total += value * 12
                else:
                    inches_total += value
            return inches_total

        # Process based on the identified keywords
        if up_to_match:
            max_height = get_inches(height_str[up_to_match.end():].strip())
            min_height = 1
        elif from_match:
            min_height = get_inches(height_str[from_match.end():].strip())
            max_height = None  # Set to None as we only have minimum
        elif to_match:
            parts = height_str.split('to')
            min_height = get_inches(parts[0].strip())
            max_height = get_inches(parts[1].strip())
        else:
            min_height = max_height = get_inches(height_str)

        return min_height, max_height

    # Apply the function to each row in the height column
    heights = df[column_name].apply(parse_height_to_inches)
    df['min_height'], df['max_height'] = zip(*heights)

    return df

process_height_column(new_df2, 'height')

new_df2[['height', 'min_height', 'max_height']]
# Out:
#                                                                              height  \
# 0                                                                   20 to 29 inches
# 1                                                                    6 to 12 inches
# 2                                        9 inches to 11 inches tall at the shoulder
# 3                                   2 feet to 2 feet, 4 inches tall at the shoulder
# 4                        1 foot, 9 inches to 1 foot, 11 inches tall at the shoulder
# 5                                                                   27 to 34 inches
# 6                                   2 feet to 2 feet, 4 inches tall at the shoulder
# 7                                                                   13 to 17 inches
# 8                          1 foot, 11 inches to 2 feet, 1 inch tall at the shoulder
# 9                                                                   20 to 28 inches
# ...

# %%
def process_lifespan_column(df, column_name):
    def parse_lifespan_to_years(lifespan_str):
        """
        Converts a lifespan string into min and max years.
        Handles single values and ranges, and phrases with 'Up to'.
        Sets min_life_span to 1 if 'Up to' is found, and calculates max_life_span based on the value provided.
        """
        if pd.isna(lifespan_str):
            return None, None

        # Check for 'Up to' at the beginning of the string
        up_to_match = re.match(r'up to', lifespan_str, re.IGNORECASE)

        # Initialize min_life_span and max_life_span
        min_life_span, max_life_span = None, None

        # Calculate years from the lifespan string
        def get_years(part):
            years = 0
            match = re.search(r'(\d+)', part)
            if match:
                years = int(match.group(1))
            return years

        if up_to_match:
            # Only max_life_span is defined after "Up to"
            min_life_span = 1
            max_life_span = get_years(lifespan_str[up_to_match.end():].strip())
        else:
            # If there is no "Up to", process normally
            parts = lifespan_str.split('to')
            min_life_span = get_years(parts[0].strip())
            max_life_span = get_years(parts[1].strip()) if len(parts) > 1 else min_life_span

        return min_life_span, max_life_span

    # Apply the function to each row in the lifespan column
    lifespans = df[column_name].apply(parse_lifespan_to_years)
    df['min_life_span'], df['max_life_span'] = zip(*lifespans)

    return df

process_lifespan_column(new_df2, "life_span")
new_df2[['life_span', 'min_life_span', 'max_life_span']]
# Out:
#                                                                 life_span  \
# 0                                                          10 to 12 years
# 1                                                          13 to 18 years
# 2                                                          12 to 14 years
# 3                                                          10 to 12 years
# 4                                                          10 to 13 years
# 5                                                          10 to 12 years
# 6                                                          10 to 12 years
# 7                                                          12 to 16 years
# 8                                                          12 to 15 years
# 9                                                          10 to 16 years
# 10                                                         10 to 12 years
# 11                                                         12 to 15 years
# ...

# %%
new_df2
# Out:
#      a2_good_for_novice_owners       breed_group  \
# 0                            1  Mixed Breed Dogs
# 1                            4  Mixed Breed Dogs
# 2                            4    Companion Dogs
# 3                            3        Hound Dogs
# 4                            2      Terrier Dogs
# 5                            2      Working Dogs
# 6                            2      Working Dogs
# 7                            2    Companion Dogs
# 8                            1      Working Dogs
# 9                            1      Working Dogs
# 10                           2        Hound Dogs
# 11                           4    Companion Dogs
# 12                           2        Hound Dogs
# 13                           4        Hound Dogs
# 14                           2      Terrier Dogs
# 15                           3  Mixed Breed Dogs
# 16                           2      Terrier Dogs
# 17                           2     Sporting Dogs
# ...

# %%
new_df2.loc[146, 'max_weight'] = 'Nan'
new_df2.loc[216, 'min_weight'] = 35.0
new_df2.loc[216, 'max_weight'] = 60.0
new_df2.loc[48, 'min_height'] = 10.0
new_df2.loc[48, 'max_height'] = 29.0
new_df2.loc[216, 'min_height'] = 18.5
new_df2.loc[216, 'max_height'] = 21
new_df2.loc[314, 'max_height'] = 23.5
new_df2.loc[30, 'min_life_span'] = 1.0

# %%
new_df2
# Out:
#      a2_good_for_novice_owners       breed_group  \
# 0                            1  Mixed Breed Dogs
# 1                            4  Mixed Breed Dogs
# 2                            4    Companion Dogs
# 3                            3        Hound Dogs
# 4                            2      Terrier Dogs
# 5                            2      Working Dogs
# 6                            2      Working Dogs
# 7                            2    Companion Dogs
# 8                            1      Working Dogs
# 9                            1      Working Dogs
# 10                           2        Hound Dogs
# 11                           4    Companion Dogs
# 12                           2        Hound Dogs
# 13                           4        Hound Dogs
# 14                           2      Terrier Dogs
# 15                           3  Mixed Breed Dogs
# 16                           2      Terrier Dogs
# 17                           2     Sporting Dogs
# ...

# %%
modified_df2 = new_df2[['a2_good_for_novice_owners', 'min_weight', 'max_weight', 'min_height', 'max_height', 'min_life_span', 'max_life_span']].copy()
modified_df2.corr()
# Out:
#                            a2_good_for_novice_owners  min_weight  max_weight  \
# a2_good_for_novice_owners                   1.000000   -0.503546   -0.482115
# min_weight                                 -0.503546    1.000000    0.925033
# max_weight                                 -0.482115    0.925033    1.000000
# min_height                                 -0.480846    0.824420    0.774291
# max_height                                 -0.519706    0.825642    0.842104
# min_life_span                               0.192384   -0.480268   -0.478397
# max_life_span                               0.261271   -0.595570   -0.549603
#
#                            min_height  max_height  min_life_span  \
# a2_good_for_novice_owners   -0.480846   -0.519706       0.192384
# min_weight                   0.824420    0.825642      -0.480268
# max_weight                   0.774291    0.842104      -0.478397
# min_height                   1.000000    0.907288      -0.308971
# ...

# %%
# Heatmap of the Correlation Matrix
f = plt.figure(figsize=(10, 10))
sb.heatmap(modified_df2.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f")
# Out:
# <Axes: >

# %% [markdown]
# Based on the correlation coefficients, we found out that the top nine variables are
# 1. A1 (0.56) - adapts well to apartment living
# 2. C6 (-0.51) - size of the dog
# 3. E3 (0.35) - exercise needs
# 4. E2 (0.32) - intensity
# 5. C2 (0.3) - drooling
# 6. B3 (0.29) - dog friendly
# 7. B4 (0.25) - friendly to strangers
# 8. D1 (0.21)  - trainability
# 9. A5 (0.21) - tolerates cold weather

# %% [markdown]
# ## Multi-Variate Classification Tree
#
# Response Variable : 'a2_good_for_novice_owners'
# Predictor Feature : **a1, a5, b3, b4, c2, c6, d1, e2, e3**

# %% [markdown]
# # using MLP

# %%
import pandas as pd
import sklearn.neural_network as sknet
import sklearn.model_selection as skmodel

# Assuming breeddata is already defined and loaded

# Extract Response and Predictors
y = data["a2_good_for_novice_owners"].values  # Directly as NumPy array
X = pd.DataFrame(data[["a1_adapts_well_to_apartment_living", "a5_tolerates_cold_weather", "b3_dog_friendly", "b4_friendly_toward_strangers", "c2_drooling_potential", "c6_size", "d1_easy_to_train", "e2_intensity", "e3_exercise_needs"]])  # predictors 

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = skmodel.train_test_split(X, y, test_size = 0.25, random_state = 4)

# MLP using Train Data
# model = sknet.MLPClassifier(hidden_layer_sizes=(150,100,50), random_state=1, max_iter=1000, solver = 'adam', activation = 'relu')

#model = sknet.MLPClassifier(hidden_layer_sizes=(200,), random_state=42)
model = sknet.MLPClassifier(hidden_layer_sizes=(100), random_state=1, max_iter=10000)
                            

model.fit(X_train, y_train)

# Predict Response corresponding to Predictors
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Accuracy
print("Accuracy on training set: {:.2%}".format(model.score(X_train, y_train)))
print("Accuracy on test set: {:.2%}".format(model.score(X_test, y_test)))
# Out:
# Accuracy on training set: 80.46%
# Accuracy on test set: 43.18%

# %%
import sklearn.metrics as skmet

cm = skmet.confusion_matrix(y_true=y_test, y_pred=y_test_pred)

cm_df = pd.DataFrame(cm,
                     index = ['1', '2', '3', '4', '5'], 
                     columns = ['1', '2', '3', '4', '5'])

#Plotting the confusion matrix
plt.figure(figsize=(5,4))
sb.heatmap(cm_df, annot=True)
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()

# %%
print(skmet.classification_report(y_test,y_test_pred))
print(skmet.classification_report(y_train,y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.14      0.17      0.15         6
#            2       0.50      0.42      0.46        26
#            3       0.33      0.35      0.34        23
#            4       0.52      0.58      0.55        26
#            5       0.50      0.43      0.46         7
#
#     accuracy                           0.43        88
#    macro avg       0.40      0.39      0.39        88
# weighted avg       0.44      0.43      0.43        88
#
#               precision    recall  f1-score   support
#
#            1       0.95      0.90      0.92        39
#            2       0.83      0.88      0.85        72
#            3       0.78      0.74      0.76        68
#            4       0.73      0.77      0.75        57
#            5       0.75      0.72      0.73        25
#
#     accuracy                           0.80       261
#    macro avg       0.81      0.80      0.80       261
# ...

# %% [markdown]
# # Using RandomForest

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Fitting Random Forest Classification to the Training set
classifier = RandomForestClassifier(n_estimators = 1000, criterion = 'log_loss', random_state = 4)
classifier.fit(X_train, y_train)
# Predicting the Test set results
y_train_pred = classifier.predict(X_train)
y_test_pred = classifier.predict(X_test)

# Accuracy
print("Accuracy on training set: {:.2%}".format(classifier.score(X_train, y_train)))
print("Accuracy on test set: {:.2%}".format(classifier.score(X_test, y_test)))
# Out:
# Accuracy on training set: 100.00%
# Accuracy on test set: 40.91%

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import ExtraTreesClassifier

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

classifier1 = ExtraTreesClassifier(n_estimators = 300, criterion = 'entropy', random_state = 4)
classifier1.fit(X_train, y_train)
# Predicting the Test set results
y_train_pred = classifier1.predict(X_train)
y_test_pred = classifier1.predict(X_test)

# Accuracy
print("Accuracy on training set: {:.2%}".format(classifier1.score(X_train, y_train)))
print("Accuracy on test set: {:.2%}".format(classifier1.score(X_test, y_test)))
# Out:
# Accuracy on training set: 100.00%
# Accuracy on test set: 40.91%

# %% [markdown]
# # Using decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# Decision Tree using Train Data
dectree = DecisionTreeClassifier(max_depth = 5)  # create the decision tree object
dectree.fit(X_train, y_train)                    # train the decision tree model

# Predict Response corresponding to Predictors
y_train_pred = dectree.predict(X_train)
y_test_pred = dectree.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", dectree.score(X_train, y_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", dectree.score(X_test, y_test))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.5747126436781609
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.45454545454545453

# %% [markdown]
# ## using Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)
yPredTrain = gnb.predict(X_train)
yPredTest = gnb.predict(X_test)  
# comparing actual response values (y_test) with predicted response values (y_pred)
from sklearn import metrics
print("Gaussian Naive Bayes model accuracy test model(in %):", metrics.accuracy_score(y_test, yPredTest)*100)
print("Gaussian Naive Bayes model accuracy train model(in %):", metrics.accuracy_score(y_train, yPredTrain)*100)
# Out:
# Gaussian Naive Bayes model accuracy test model(in %): 42.04545454545455
# Gaussian Naive Bayes model accuracy train model(in %): 44.06130268199234

# %%
print(skmet.classification_report(y_test,yPredTest))
print(skmet.classification_report(y_train,yPredTrain))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.22      0.33      0.27         6
#            2       0.40      0.38      0.39        26
#            3       0.38      0.35      0.36        23
#            4       0.59      0.50      0.54        26
#            5       0.36      0.57      0.44         7
#
#     accuracy                           0.42        88
#    macro avg       0.39      0.43      0.40        88
# weighted avg       0.44      0.42      0.42        88
#
#               precision    recall  f1-score   support
#
#            1       0.52      0.59      0.55        39
#            2       0.44      0.43      0.44        72
#            3       0.41      0.35      0.38        68
#            4       0.38      0.35      0.36        57
#            5       0.49      0.68      0.57        25
#
#     accuracy                           0.44       261
#    macro avg       0.45      0.48      0.46       261
# ...
